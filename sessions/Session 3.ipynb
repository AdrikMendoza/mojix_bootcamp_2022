# %% [markdown]
# # Session 3

# %%
import pandas as pd

# %%
df = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 208793      ZWE    Africa  Zimbabwe  2022-08-10     256492.0        2.0
# 208794      ZWE    Africa  Zimbabwe  2022-08-11     256513.0       21.0
# 208795      ZWE    Africa  Zimbabwe  2022-08-12     256522.0        9.0
# 208796      ZWE    Africa  Zimbabwe  2022-08-13     256522.0        0.0
# 208797      ZWE    Africa  Zimbabwe  2022-08-14     256539.0       17.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 208793               9.857        5587.0         1.0                1.143
# 208794               9.857        5587.0         0.0                0.857
# 208795              11.143        5587.0         0.0                0.857
# 208796              11.143        5587.0         0.0                0.857
# 208797              13.143        5588.0         1.0                0.571
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df.shape
# Out:
# (208798, 67)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208798 entries, 0 to 208797
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    208798 non-null  object
#  1   continent                                   196736 non-null  object
#  2   location                                    208798 non-null  object
#  3   date                                        208798 non-null  object
#  4   total_cases                                 200303 non-null  float64
#  5   new_cases                                   199943 non-null  float64
#  6   new_cases_smoothed                          198766 non-null  float64
#  7   total_deaths                                181503 non-null  float64
#  8   new_deaths                                  181458 non-null  float64
# ...

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.003030e+05  1.999430e+05        1.987660e+05  1.815030e+05
# mean   3.883470e+06  1.260101e+04        1.262553e+04  6.954749e+04
# std    2.437056e+07  8.724042e+04        8.526486e+04  3.601170e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    3.513500e+03  0.000000e+00        6.714000e+00  1.040000e+02
# 50%    4.240400e+04  6.400000e+01        1.004290e+02  1.051000e+03
# 75%    4.570540e+05  1.011000e+03        1.155250e+03  9.155500e+03
# max    5.903313e+08  4.079204e+06        3.436703e+06  6.435631e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  181458.00000        180286.000000            199383.000000
# mean      147.15942           147.918030             51112.958998
# std       757.77861           741.376692             93067.825939
# min         0.00000             0.000000                 0.001000
# ...

# %%
df['location'].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# human_development_index                    float64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %%
df[['location', 'continent']]
# Out:
#            location continent
# 0       Afghanistan      Asia
# 1       Afghanistan      Asia
# 2       Afghanistan      Asia
# 3       Afghanistan      Asia
# 4       Afghanistan      Asia
# ...             ...       ...
# 208793     Zimbabwe    Africa
# 208794     Zimbabwe    Africa
# 208795     Zimbabwe    Africa
# 208796     Zimbabwe    Africa
# 208797     Zimbabwe    Africa
#
# [208798 rows x 2 columns]

# %%
df.loc[df['iso_code']=='AFG']
# Out:
#     iso_code continent     location        date  total_cases  new_cases  \
# 0        AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1        AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2        AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3        AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4        AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ..       ...       ...          ...         ...          ...        ...
# 898      AFG      Asia  Afghanistan  2022-08-10     188202.0      236.0
# 899      AFG      Asia  Afghanistan  2022-08-11     188506.0      304.0
# 900      AFG      Asia  Afghanistan  2022-08-12     188704.0      198.0
# 901      AFG      Asia  Afghanistan  2022-08-13     188820.0      116.0
# 902      AFG      Asia  Afghanistan  2022-08-14     189045.0      225.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.loc[(df['iso_code']=='AFG')&(df['total_cases']==188202.0)]
# Out:
#     iso_code continent     location        date  total_cases  new_cases  \
# 898      AFG      Asia  Afghanistan  2022-08-10     188202.0      236.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 898             258.429        7753.0         0.0                0.143  ...
#
#      female_smokers  male_smokers  handwashing_facilities  \
# 898             NaN           NaN                  37.746
#
#      hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 898                         0.5            64.83                    0.511
#
#      excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 898                                   NaN                          NaN
#
#      excess_mortality  excess_mortality_cumulative_per_million
# 898               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
df.loc[(df['iso_code']=='AFG')&(df['total_cases']==188202.0), 'continent'] = 'Asian'

# %%
df.loc[(df['iso_code']=='AFG')&(df['total_cases']==188202.0)]
# Out:
#     iso_code continent     location        date  total_cases  new_cases  \
# 898      AFG     Asian  Afghanistan  2022-08-10     188202.0      236.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 898             258.429        7753.0         0.0                0.143  ...
#
#      female_smokers  male_smokers  handwashing_facilities  \
# 898             NaN           NaN                  37.746
#
#      hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 898                         0.5            64.83                    0.511
#
#      excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 898                                   NaN                          NaN
#
#      excess_mortality  excess_mortality_cumulative_per_million
# 898               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
df.iloc[[100, 200, 4]]
# Out:
#     iso_code continent     location        date  total_cases  new_cases  \
# 100      AFG      Asia  Afghanistan  2020-06-03      17353.0      775.0
# 200      AFG      Asia  Afghanistan  2020-09-11      38692.0       34.0
# 4        AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 100             698.286         298.0        24.0                9.714  ...
# 200              45.429        1424.0         0.0                1.571  ...
# 4                   NaN           NaN         NaN                  NaN  ...
#
#      female_smokers  male_smokers  handwashing_facilities  \
# 100             NaN           NaN                  37.746
# 200             NaN           NaN                  37.746
# 4               NaN           NaN                  37.746
#
#      hospital_beds_per_thousand  life_expectancy  human_development_index  \
# ...

# %%
df.describe().loc['mean']
# Out:
# total_cases                                3.883470e+06
# new_cases                                  1.260101e+04
# new_cases_smoothed                         1.262553e+04
# total_deaths                               6.954749e+04
# new_deaths                                 1.471594e+02
#                                                ...
# human_development_index                    7.249795e-01
# excess_mortality_cumulative_absolute       4.443878e+04
# excess_mortality_cumulative                9.622816e+00
# excess_mortality                           1.472629e+01
# excess_mortality_cumulative_per_million    1.219058e+03
# Name: mean, Length: 62, dtype: float64

# %%
df['new_cases'].mean()
# Out:
# 12601.009442691167

# %%
df['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
len(df['location'].unique())
# Out:
# 244

# %%
df['location'].nunique()
# Out:
# 244

# %%
pd.DataFrame(df['location'].unique())
# Out:
#                   0
# 0       Afghanistan
# 1            Africa
# 2           Albania
# 3           Algeria
# 4           Andorra
# ..              ...
# 239  Western Sahara
# 240           World
# 241           Yemen
# 242          Zambia
# 243        Zimbabwe
#
# [244 rows x 1 columns]

# %%
df.sample(500)
# Out:
#        iso_code      continent                   location        date  \
# 2681        ALB         Europe                    Albania  2022-07-08
# 97265       JOR           Asia                     Jordan  2022-03-12
# 159635      SPM  North America  Saint Pierre and Miquelon  2021-05-09
# 29411       BGR         Europe                   Bulgaria  2022-03-27
# 183484      TJK           Asia                 Tajikistan  2020-05-06
# ...         ...            ...                        ...         ...
# 91083       IRL         Europe                    Ireland  2021-07-15
# 84975       HUN         Europe                    Hungary  2022-03-16
# 106207      LBR         Africa                    Liberia  2021-04-04
# 38899       CHN           Asia                      China  2021-03-02
# 104759      LBN           Asia                    Lebanon  2021-12-17
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
df['continent'].replace("Asian", "Asia", inplace=True)

# %%
df['continent'].value_counts()
# Out:
# Africa           48328
# Europe           45302
# Asia             44982
# North America    32258
# Oceania          14243
# South America    11623
# Name: continent, dtype: int64

# %%
df.rename(columns={"new_deaths":"new_deaths_new"}, inplace=True)

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths_new',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df.rename(columns={"new_deaths_new":"new_deaths"}, inplace=True)

# %%
#groupby
df.groupby('continent').count()
# Out:
#                iso_code  location   date  total_cases  new_cases  \
# continent
# Africa            48328     48328  48328        48239      48177
# Asia              44982     44982  44982        43511      43418
# Europe            45302     45302  45302        44132      44018
# North America     32258     32258  32258        30059      30010
# Oceania           14243     14243  14243        10747      10723
# South America     11623     11623  11623        11560      11535
#
#                new_cases_smoothed  total_deaths  new_deaths  \
# continent
# Africa                      47896         45644       45621
# Asia                        43168         39589       39565
# Europe                      43760         41771       41632
# North America               29840         25815       25784
# Oceania                     10643          6298        6288
# South America               11462         10537       10519
#
# ...

# %%
df.groupby('continent').size()
# Out:
# continent
# Africa           48328
# Asia             44982
# Europe           45302
# North America    32258
# Oceania          14243
# South America    11623
# dtype: int64

# %%
df.groupby(['continent', 'location']).count()
# Out:
#                             iso_code  date  total_cases  new_cases  \
# continent     location
# Africa        Algeria            902   902          902        902
#               Angola             878   878          878        878
#               Benin              882   882          882        881
#               Botswana           868   868          868        865
#               Burkina Faso       888   888          888        888
# ...                              ...   ...          ...        ...
# South America Paraguay           891   891          890        888
#               Peru               892   892          892        890
#               Suriname           884   884          884        884
#               Uruguay            885   885          885        879
#               Venezuela          884   884          884        884
#
#                             new_cases_smoothed  total_deaths  new_deaths  \
# continent     location
# ...

# %%
df.groupby(['continent', 'location']).count()[['new_deaths_smoothed']]
# Out:
#                             new_deaths_smoothed
# continent     location
# Africa        Algeria                       881
#               Angola                        863
#               Benin                         856
#               Botswana                      862
#               Burkina Faso                  875
# ...                                         ...
# South America Paraguay                      871
#               Peru                          884
#               Suriname                      859
#               Uruguay                       865
#               Venezuela                     865
#
# [231 rows x 1 columns]

# %%
df.groupby(['continent', 'location']).count()[['new_deaths_smoothed']].rename(columns={'new_deaths_smoothed':'deaths_smoothed'})
# Out:
#                             deaths_smoothed
# continent     location
# Africa        Algeria                   881
#               Angola                    863
#               Benin                     856
#               Botswana                  862
#               Burkina Faso              875
# ...                                     ...
# South America Paraguay                  871
#               Peru                      884
#               Suriname                  859
#               Uruguay                   865
#               Venezuela                 865
#
# [231 rows x 1 columns]

# %%
# Sorting

df_aux = df.groupby(['continent', 'location']).count()[['new_deaths_smoothed']].rename(columns={'new_deaths_smoothed':'deaths_smoothed'})
df_aux.sort_values('deaths_smoothed', ascending=False)
# Out:
#                                             deaths_smoothed
# continent     location
# Asia          China                                     927
#               Philippines                               918
#               Hong Kong                                 918
#               Japan                                     909
#               Taiwan                                    906
# ...                                                     ...
# North America United States Virgin Islands                0
# Oceania       Tokelau                                     0
#               Niue                                        0
#               Northern Mariana Islands                    0
#               Nauru                                       0
#
# [231 rows x 1 columns]

# %%
df_aux_sorted = df_aux.sort_values('deaths_smoothed', ascending=False)
df_aux_sorted = df_aux_sorted.reset_index()

# %%
# Pivot Table

df_aux_sorted['location'].nunique()
# Out:
# 231

# %%
df_aux_sorted['continent'].nunique()
# Out:
# 6

# %%
df_aux_sorted.head()
# Out:
#   continent     location  deaths_smoothed
# 0      Asia        China              927
# 1      Asia  Philippines              918
# 2      Asia    Hong Kong              918
# 3      Asia        Japan              909
# 4      Asia       Taiwan              906

# %%
# Pivot Table

df_aux_sorted.pivot_table(values='deaths_smoothed', index='location', columns='continent').fillna("")
# Out:
# continent         Africa   Asia Europe North America Oceania South America
# location
# Afghanistan               870.0
# Albania                          882.0
# Algeria            881.0
# Andorra                          870.0
# Angola             863.0
# ...                  ...    ...    ...           ...     ...           ...
# Wallis and Futuna                                      507.0
# Western Sahara       0.0
# Yemen                     832.0
# Zambia             860.0
# Zimbabwe           870.0
#
# [231 rows x 6 columns]

# %%
final = df_aux_sorted.pivot_table(values='deaths_smoothed', index='location', columns='continent').fillna("")

# %%
df_a = final.reset_index()
df_a
# Out:
# continent           location Africa   Asia Europe North America Oceania  \
# 0                Afghanistan         870.0
# 1                    Albania                882.0
# 2                    Algeria  881.0
# 3                    Andorra                870.0
# 4                     Angola  863.0
# ..                       ...    ...    ...    ...           ...     ...
# 226        Wallis and Futuna                                      507.0
# 227           Western Sahara    0.0
# 228                    Yemen         832.0
# 229                   Zambia  860.0
# 230                 Zimbabwe  870.0
#
# continent South America
# 0
# 1
# 2
# 3
# 4
# ..                  ...
# 226
# 227
# 228
# 229
# 230
#
# [231 rows x 7 columns]

# %%
df_b = pd.DataFrame({'location':['Zimbabwe', 'Zambia', 'Albania'], 'red_flag':["yes", "yes", "TBD"]})
df_b
# Out:
#    location red_flag
# 0  Zimbabwe      yes
# 1    Zambia      yes
# 2   Albania      TBD

# %%
df_merge = pd.merge(df_a, df_b, on='location', how='outer', indicator=True)
df_merge
# Out:
#               location Africa   Asia Europe North America Oceania  \
# 0          Afghanistan         870.0
# 1              Albania                882.0
# 2              Algeria  881.0
# 3              Andorra                870.0
# 4               Angola  863.0
# ..                 ...    ...    ...    ...           ...     ...
# 226  Wallis and Futuna                                      507.0
# 227     Western Sahara    0.0
# 228              Yemen         832.0
# 229             Zambia  860.0
# 230           Zimbabwe  870.0
#
#     South America red_flag     _merge
# 0                      NaN  left_only
# 1                      TBD       both
# 2                      NaN  left_only
# 3                      NaN  left_only
# 4                      NaN  left_only
# ..            ...      ...        ...
# 226                    NaN  left_only
# 227                    NaN  left_only
# 228                    NaN  left_only
# 229                    yes       both
# ...

# %%
df_merge.groupby('_merge').count()
# Out:
#             location  Africa  Asia  Europe  North America  Oceania  \
# _merge
# left_only        228     228   228     228            228      228
# right_only         0       0     0       0              0        0
# both               3       3     3       3              3        3
#
#             South America  red_flag
# _merge
# left_only             228         0
# right_only              0         0
# both                    3         3
